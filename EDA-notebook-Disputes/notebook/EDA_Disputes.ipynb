# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
n

# %%
file_name="../data/consumer_complaints.csv"
df = pd.read_csv(file_name)
# Out:
# /var/folders/wn/nj1blbjd4g5b3cl1hg7vr2bh0000gn/T/ipykernel_34219/1751158270.py:2: DtypeWarning: Columns (0: consumer_complaint_narrative, 1: consumer_consent_provided) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_name)
